# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import expansion_hard_disks.simulation as ehs

# %%
# %%time
ehs.initialize()
ehs.prolonged_growth(3000) # displays the percentage of completion
ehs.display_colony()
# Out:
# 10.0
# 20.0
# 30.0
# 40.0
# 50.0
# 60.0
# 70.0
# 80.0
# 90.0
# CPU times: user 3.69 s, sys: 54.5 ms, total: 3.75 s
# Wall time: 3.74 s

# %%
ehs.prolonged_growth(10000) # displays the percentage of completion
ehs.display_colony()
# Out:
# 10.0
# 20.0
# 30.0
# 40.0
# 50.0
# 60.0
# 70.0
# 80.0
# 90.0

# %%
# when more than 20000 cells are present, the colony is displayed coarse-grained. The default resolution is 1 px = 16 cells
ehs.prolonged_growth(500000) # displays the percentage of completion
ehs.display_colony()
# Out:
# 10.0
# 20.0
# 30.0
# 40.0
# 50.0
# 60.0
# 70.0
# 80.0
# 90.0

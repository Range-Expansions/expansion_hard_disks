# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import expansion_hard_disks.simulation as ehs

# %%
ehs.positions
# Out:
# array([[ 0.        ,  0.        ,  1.        ],
#        [ 2.        ,  0.        ,  1.20000005]])

# %%
# %%time
ehs.prolonged_growth(1000)
# Out:
# 10.0
# 20.0
# 30.0
# 40.0
# 50.0
# 60.0
# 70.0
# 80.0
# 90.0
# CPU times: user 432 ms, sys: 8.56 ms, total: 441 ms
# Wall time: 435 ms

# %%
ehs.display_colony()

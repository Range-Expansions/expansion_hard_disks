# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import expansion_hard_disks.simulation as ehs

# %%
# %%time
ehs.initialize()
ehs.prolonged_growth(1000)
# Out:
# 10.0
# 20.0
# 30.0
# 40.0
# 50.0
# 60.0
# 70.0
# 80.0
# 90.0
# CPU times: user 1.07 s, sys: 7.24 ms, total: 1.07 s
# Wall time: 1.07 s

# %%
ehs.display_colony()

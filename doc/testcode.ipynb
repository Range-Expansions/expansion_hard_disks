# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import expansion_hard_disks.simulation as ehs

# %%
# Initialize a ring, giving the fraction of space occupied by cells within the ring
ehs.initialize_ring(0.2)
# One can also initialize a disk, giving the fraction of space occupied by cells within the disk:
# ehs.initialize_disk(0.3)
ehs.display_colony_circles()

# %%
# Perform 30000 cell divisions, displays command completion percentage and real time in 
# units of r1 (which is initially set to 1)
ehs.prolonged_growth(10000)
ehs.display_colony_circles()
# Out:
# Completion:  10.0 % - Time:  6.24048280716
# Completion:  20.0 % - Time:  6.4475736618
# Completion:  30.0 % - Time:  6.6081328392
# Completion:  40.0 % - Time:  6.74673986435
# Completion:  50.0 % - Time:  6.8556227684
# Completion:  60.0 % - Time:  6.94710969925
# Completion:  70.0 % - Time:  7.03279590607
# Completion:  80.0 % - Time:  7.10670948029
# Completion:  90.0 % - Time:  7.17224025726
# Completion:  100.0 % - Time:  7.23066616058

# %%
# Growth rates are switched at time t=4
ehs.prolonged_growth(30000) # displays the percentage of completion
ehs.display_colony_circles()
# Out:
# Completion:  10.0 % - Time:  3.91104650497
# Completion:  20.0 % - Time:  3.99472379684
# Switched growth rates
# Completion:  30.0 % - Time:  4.0491027832
# Completion:  40.0 % - Time:  4.09621572495
# Completion:  50.0 % - Time:  4.14072465897
# Completion:  60.0 % - Time:  4.18399477005
# Completion:  70.0 % - Time:  4.22363519669
# Completion:  80.0 % - Time:  4.26132202148
# Completion:  90.0 % - Time:  4.2970995903
# Completion:  100.0 % - Time:  4.33134937286

# %%
ehs.prolonged_growth(100000)
# When the colony is too large it's faster to plot a coarse-grained version
ehs.display_colony()
# Out:
# Completion:  10.0 % - Time:  4.43182277679
# Completion:  20.0 % - Time:  4.52008581161
# Completion:  30.0 % - Time:  4.59966087341
# Completion:  40.0 % - Time:  4.67010641098
# Completion:  50.0 % - Time:  4.73185825348
# Completion:  60.0 % - Time:  4.78805780411
# Completion:  70.0 % - Time:  4.84115886688
# Completion:  80.0 % - Time:  4.89069843292
# Completion:  90.0 % - Time:  4.93606901169
# Completion:  100.0 % - Time:  4.97900867462
